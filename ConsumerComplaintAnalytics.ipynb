# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# connect to the csv file and load the data
consumer = pd.read_csv('complaints-2025-09-03_15_50.csv')
consumer.head()
# Out:
#   Date received                                            Product  \
# 0      10/23/23  Credit reporting or other personal consumer re...
# 1      07/07/23  Credit reporting, credit repair services, or o...
# 2      11/28/23  Credit reporting or other personal consumer re...
# 3      10/08/23  Credit reporting or other personal consumer re...
# 4      02/15/23  Credit reporting, credit repair services, or o...
#
#         Sub-product                                 Issue  \
# 0  Credit reporting           Improper use of your report
# 1  Credit reporting           Improper use of your report
# 2  Credit reporting           Improper use of your report
# 3  Credit reporting  Incorrect information on your report
# 4  Credit reporting  Incorrect information on your report
#
#                                            Sub-issue  \
# 0  Credit inquiries on your report that you don't...
# 1      Reporting company used your report improperly
# 2      Reporting company used your report improperly
# 3                Information belongs to someone else
# 4                      Account information incorrect
#
#                         Consumer complaint narrative  \
# 0  On XX/XX/XXXX I received notification that the...
# 1  15 U.S. Code $ 1681c-2 a consumer reporting ag...
# 2  My credit reports are inaccurate. These inaccu...
# 3                                                NaN
# 4                                                NaN
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1                                                NaN
# 2  Company has responded to the consumer and the ...
# 3  Company has responded to the consumer and the ...
# 4                                                NaN
#
#                                   Company State ZIP code           Tags  \
# 0  TRANSUNION INTERMEDIATE HOLDINGS, INC.    MD    21209            NaN
# 1                    JPMORGAN CHASE & CO.    CA    95949            NaN
# 2     Experian Information Solutions Inc.    GA    XXXXX            NaN
# 3  TRANSUNION INTERMEDIATE HOLDINGS, INC.    WI    53089            NaN
# 4               ENCORE CAPITAL GROUP INC.    TX    76502  Servicemember
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web             10/23/23
# 1           Consent provided           Web             07/07/23
# 2           Consent provided           Web             11/28/23
# 3       Consent not provided           Web             10/08/23
# 4       Consent not provided           Web             02/15/23
#
#       Company response to consumer Timely response?  Consumer disputed?  \
# 0          Closed with explanation              Yes                 NaN
# 1          Closed with explanation              Yes                 NaN
# 2          Closed with explanation              Yes                 NaN
# 3  Closed with non-monetary relief              Yes                 NaN
# 4  Closed with non-monetary relief              Yes                 NaN
#
#    Complaint ID
# 0       7741393
# 1       7219680
# 2       7907685
# 3       7662117
# 4       6575908

# %%
# showing the count and percent of nulls 
missing_values = pd.DataFrame({
    'Data Type': consumer.dtypes,
    'Null Count': consumer.isnull().sum(),
    'Null %': consumer.isnull().mean() * 100
})
missing_values
# Out:
#                              Data Type  Null Count      Null %
# Date received                   object           0    0.000000
# Product                         object           0    0.000000
# Sub-product                     object           0    0.000000
# Issue                           object           0    0.000000
# Sub-issue                       object       40784    3.156395
# Consumer complaint narrative    object      804662   62.275183
# Company public response         object      525878   40.699261
# Company                         object           0    0.000000
# State                           object        3605    0.279002
# ZIP code                        object         110    0.008513
# Tags                            object     1201545   92.991138
# Consumer consent provided?      object       35903    2.778640
# Submitted via                   object           0    0.000000
# Date sent to company            object           0    0.000000
# Company response to consumer    object           6    0.000464
# Timely response?                object           0    0.000000
# Consumer disputed?             float64     1292107  100.000000
# Complaint ID                     int64           0    0.000000

# %%
# seeing how often data received is different than date sent
consumer['Date_diff'] = consumer['Date received'] != consumer['Date sent to company']
consumer['Date_diff'].value_counts()
# Out:
# Date_diff
# False    1246372
# True       45735
# Name: count, dtype: int64

# %%
# creating a column that subtracts date received from date sent to company to see how long companies take to respond
consumer['Response Time'] = pd.to_datetime(consumer['Date sent to company'], format='mixed') - pd.to_datetime(consumer['Date received'], format='mixed')
consumer['Response Time'] = consumer['Response Time'].dt.days
consumer['Response Time'] = pd.to_numeric(consumer['Response Time'], errors='coerce')
consumer['Response Time'].describe()
# Out:
# count    1.292107e+06
# mean     5.291241e-01
# std      4.326170e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.110000e+02
# Name: Response Time, dtype: float64

# %%
#filter data to exclude less than a day response time and extreme outliers
consumer_responsetime = consumer[(consumer['Response Time'] > 1) & (consumer['Response Time'] < 50)]

# histogram of booking values
plt.figure(figsize=(10,6))
sns.histplot(consumer_responsetime['Response Time'], bins=50, kde=True)
plt.title('Distribution of Response Times (Days)')
plt.xlabel('Response Time (Days)')
plt.ylabel('Frequency')
plt.show()

# %%
# inspecting company complaint counts and response times
company_response = consumer.groupby('Company').agg(
    Response_Time_Mean=('Response Time', 'mean'),
    Complaint_Count=('Complaint ID', 'count')
).reset_index()

# sort by average response time in descending order
company_response = company_response.sort_values(by='Complaint_Count', ascending=False)
company_response.head(15)
# Out:
#                                      Company  Response_Time_Mean  \
# 3006  TRANSUNION INTERMEDIATE HOLDINGS, INC.            0.084969
# 1130                           EQUIFAX, INC.            0.081001
# 1195     Experian Information Solutions Inc.            0.092453
# 3283                   WELLS FARGO & COMPANY            0.828540
# 560        CAPITAL ONE FINANCIAL CORPORATION            1.066984
# 1682                    JPMORGAN CHASE & CO.            0.824207
# 397    BANK OF AMERICA, NATIONAL ASSOCIATION            0.958924
# 606                           CITIBANK, N.A.            1.716313
# 2781                     SYNCHRONY FINANCIAL            2.477942
# 80                  AMERICAN EXPRESS COMPANY            0.800850
# 514           Bread Financial Holdings, Inc.            3.426392
# 1016                           DISCOVER BANK            0.583957
# 2648         Resurgent Capital Services L.P.            1.304678
# 1793                              LEXISNEXIS            0.542133
# 2147               NAVY FEDERAL CREDIT UNION            0.438062
#
#       Complaint_Count
# 3006           342703
# 1130           329181
# 1195           306868
# 3283            20722
# 560             17019
# 1682            15615
# 397             14315
# 606              9796
# 2781             7095
# 80               6116
# 514              5964
# 1016             5211
# 2648             5130
# 1793             4379
# 2147             4335

# %%
#looking to see if each company has multiple zip codes associated with it
company_zip = consumer.groupby('Company').agg(
    Zipcode_Values=('ZIP code', lambda x: x.dropna().unique().tolist())
).reset_index()
company_zip.head(15)
# Out:
#                                      Company  \
# 0                       1 Auto Finance, Inc.
# 1                 16 Hands LLC. dba Fiducius
# 2                          1803 Capital, LLC
# 3             1ST 2ND MORTGAGE CO. OF NJ INC
# 4   1ST RESULTS BILLINGS & COLLECTIONS, INC.
# 5         1st Franklin Financial Corporation
# 6                   208 Capital Holdings LLC
# 7                        21ST MORTGAGE CORP.
# 8                     2233 Paradise Road LLC
# 9                       2288984 Ontario Inc.
# 10                          3D Financial, LP
# 11                      3rd Generation, Inc.
# 12                       4M Collections, LLC
# 13                      60 Month Loans, Inc.
# 14                        9 Dots Lending LLC
#
#                                        Zipcode_Values
# 0                                             [60123]
# 1                                             [71201]
# 2   [70122, 302XX, 30274, 97123, 312XX, 33021, 335...
# 3                                             [08075]
# 4                                             [27262]
# 5   [29073, 30092, 306XX, 296XX, 70461, 35810, 432...
# 6                                             [83442]
# 7   [75050, 474XX, 49548, 49444, 32118, XXXXX, 731...
# 8                                      [76513, XXXXX]
# 9   [323XX, 78728, 33139, 46970, 351XX, 656XX, 542...
# 10                                            [384XX]
# 11  [30344, 98908, 78132, 95824, 89102, 85225, 960...
# 12                              [97123, 91316, 98665]
# 13                                     [84044, XXXXX]
# 14                                            [80123]

# %%
#bar plot of top 10 issue types, made horizontal for better readability
plt.figure(figsize=(10,8))
top_10_issues = consumer['Issue'].value_counts().nlargest(10).index
sns.countplot(y='Issue', data=consumer[consumer['Issue'].isin(top_10_issues)], hue='Issue', palette='rocket', order=top_10_issues, legend=False)
plt.title('Count of Top 10 Issue Types')
plt.xlabel('Count')
plt.ylabel('Issue Type')
plt.show()

# %%
# List of banks to filter by
#I asked Claude to identify the banks from the top 50 companies by complaint count to create this list
banks = [
    "WELLS FARGO & COMPANY",
    "JPMORGAN CHASE & CO.",
    "BANK OF AMERICA, NATIONAL ASSOCIATION",
    "CITIBANK, N.A.",
    "U.S. BANCORP",
    "TRUIST FINANCIAL CORPORATION",
    "TD BANK US HOLDING COMPANY",
    "GOLDMAN SACHS BANK USA",
    "BARCLAYS BANK DELAWARE",
    "SANTANDER HOLDINGS USA, INC.",
    "PNC Bank N.A.",
    "CITIZENS FINANCIAL GROUP, INC.",
    "DISCOVER BANK",
    "CAPITAL ONE FINANCIAL CORPORATION",
    "SYNCHRONY FINANCIAL",
    "AMERICAN EXPRESS COMPANY",
    "ALLY FINANCIAL INC.",
    "NAVY FEDERAL CREDIT UNION"
]

#filtering the consumer dataframe to include only the specified banks
bank_complaints = consumer[consumer['Company'].isin(banks)]
bank_complaints.head()
# Out:
#    Date received                                            Product  \
# 1       07/07/23  Credit reporting, credit repair services, or o...
# 25      01/06/23                        Credit card or prepaid card
# 32      04/25/23  Credit reporting, credit repair services, or o...
# 34      03/23/23                        Checking or savings account
# 42      01/02/23                        Checking or savings account
#
#                                    Sub-product  \
# 1                             Credit reporting
# 25  General-purpose credit card or charge card
# 32                            Credit reporting
# 34                            Checking account
# 42                             Savings account
#
#                                                 Issue  \
# 1                         Improper use of your report
# 25                 Other features, terms, or problems
# 32               Incorrect information on your report
# 34  Problem with a lender or other company chargin...
# 42                                 Opening an account
#
#                                         Sub-issue  \
# 1   Reporting company used your report improperly
# 25          Problem with rewards from credit card
# 32                       Account status incorrect
# 34                 Transaction was not authorized
# 42            Account opened as a result of fraud
#
#                          Consumer complaint narrative  \
# 1   15 U.S. Code $ 1681c-2 a consumer reporting ag...
# 25                                                NaN
# 32  Credit bureaus reporting as delinquent. My acc...
# 34                                                NaN
# 42  A Bank of America XXXX XXXX account was opened...
#
#                               Company public response  \
# 1                                                 NaN
# 25                                                NaN
# 32                                                NaN
# 34                                                NaN
# 42  Company has responded to the consumer and the ...
#
#                                   Company State ZIP code Tags  \
# 1                    JPMORGAN CHASE & CO.    CA    95949  NaN
# 25                 GOLDMAN SACHS BANK USA    FL    32003  NaN
# 32      CAPITAL ONE FINANCIAL CORPORATION    FL    337XX  NaN
# 34                   JPMORGAN CHASE & CO.    NY    10705  NaN
# 42  BANK OF AMERICA, NATIONAL ASSOCIATION    MI    48185  NaN
#
#    Consumer consent provided? Submitted via Date sent to company  \
# 1            Consent provided           Web             07/07/23
# 25                        NaN         Phone             01/06/23
# 32           Consent provided           Web             04/25/23
# 34       Consent not provided           Web             03/23/23
# 42           Consent provided           Web             01/02/23
#
#        Company response to consumer Timely response?  Consumer disputed?  \
# 1           Closed with explanation              Yes                 NaN
# 25          Closed with explanation              Yes                 NaN
# 32          Closed with explanation              Yes                 NaN
# 34          Closed with explanation              Yes                 NaN
# 42  Closed with non-monetary relief              Yes                 NaN
#
#     Complaint ID  Date_diff  Response Time
# 1        7219680      False              0
# 25       6407464      False              0
# 32       6880689      False              0
# 34       6736180      False              0
# 42       6389050      False              0

# %%
#create a count of unique Issue types per bank
bank_issue_counts = bank_complaints.groupby('Company')['Issue'].nunique().reset_index()
bank_issue_counts.columns = ['Company', 'Unique Issue Count']
bank_issue_counts = bank_issue_counts.sort_values(by='Unique Issue Count', ascending=False)
bank_issue_counts
# Out:
#                                   Company  Unique Issue Count
# 17                  WELLS FARGO & COMPANY                  75
# 9                    JPMORGAN CHASE & CO.                  72
# 2   BANK OF AMERICA, NATIONAL ASSOCIATION                  70
# 4       CAPITAL ONE FINANCIAL CORPORATION                  65
# 6          CITIZENS FINANCIAL GROUP, INC.                  65
# 13                    SYNCHRONY FINANCIAL                  65
# 16                           U.S. BANCORP                  65
# 10              NAVY FEDERAL CREDIT UNION                  64
# 5                          CITIBANK, N.A.                  63
# 11                          PNC Bank N.A.                  60
# 14             TD BANK US HOLDING COMPANY                  60
# 7                           DISCOVER BANK                  59
# 15           TRUIST FINANCIAL CORPORATION                  59
# 0                     ALLY FINANCIAL INC.                  56
# 1                AMERICAN EXPRESS COMPANY                  55
# 8                  GOLDMAN SACHS BANK USA                  54
# 12           SANTANDER HOLDINGS USA, INC.                  52
# 3                  BARCLAYS BANK DELAWARE                  44

# %%
# using the bank_complaints, Create a table of Issues with a total count of complaints for each unique issue
issue_counts = bank_complaints['Issue'].value_counts().reset_index()
issue_counts.columns = ['Issue', 'Complaint Count']
issue_counts['Issue Percent'] = (issue_counts['Complaint Count'] / issue_counts['Complaint Count'].sum()) * 100
issue_counts.head(25)
# Out:
#                                                 Issue  Complaint Count  \
# 0                                 Managing an account            20776
# 1                         Improper use of your report            14202
# 2                Incorrect information on your report            12421
# 3     Problem with a purchase shown on your statement            10609
# 4                               Getting a credit card             5760
# 5                                  Closing an account             4935
# 6                  Other features, terms, or problems             4864
# 7   Problem with a lender or other company chargin...             4114
# 8                                    Fees or interest             3525
# 9                                  Opening an account             3486
# 10  Problem with a credit reporting company's inve...             3215
# 11                       Problem when making payments             2924
# 12                  Attempts to collect debt not owed             2816
# 13             Problem caused by your funds being low             2754
# 14                               Closing your account             2560
# 15                                      Fraud or scam             2550
# 16                     Trouble during payment process             2548
# 17  Problem with a company's investigation into an...             2166
# 18                         Struggling to pay mortgage             2077
# 19                         Managing the loan or lease             1861
# 20  Advertising and marketing, including promotion...             1785
# 21                            Trouble using your card             1557
# 22                             Trouble using the card             1117
# 23  Applying for a mortgage or refinancing an exis...              979
# 24                          Other transaction problem              956
#
#     Issue Percent
# 0       16.288770
# 1       11.134632
# 2        9.738295
# 3        8.317653
# 4        4.515947
# 5        3.869132
# 6        3.813466
# 7        3.225452
# 8        2.763665
# 9        2.733089
# 10       2.520620
# 11       2.292470
# 12       2.207796
# 13       2.159187
# 14       2.007088
# 15       1.999247
# 16       1.997679
# 17       1.698184
# 18       1.628407
# 19       1.459059
# 20       1.399473
# 21       1.220717
# 22       0.875749
# 23       0.767554
# 24       0.749522

# %% [markdown]
# ## Definitions of Common Issues
# **Managing an account**<br>
# This covers problems consumers have with day-to-day account management, such as:
#
# * Difficulty accessing online banking or mobile apps
# * Problems opening, closing, or changing account features
# * Issues with account statements or notifications
# * Customer service problems when trying to manage the account
# * Restrictions placed on accounts without clear explanation
#
# **Improper use of your report**<br>
# This refers to misuse of consumer credit reports, including:
#
# * Companies pulling your credit report without permission (unauthorized hard inquiries)
# * Employers or landlords accessing reports inappropriately
# * Identity thieves using your information to access credit reports
# * Credit reports being used for purposes not allowed by law
# * Reports being shared with unauthorized third parties
#
# **Incorrect information on your report**<br>
# These are disputes about inaccurate data on credit reports:
#
# * Wrong personal information (names, addresses, Social Security numbers)
# * Accounts that don't belong to you appearing on your report
# * Incorrect payment history or account status
# * Accounts showing as open when they're closed (or vice versa)
# * Wrong balances, credit limits, or dates
# * Information that should have been removed but wasn't
#
# **Problem with a purchase shown on your statement**<br>
# This involves billing disputes and transaction issues:
#
# * Charges for items you didn't purchase or authorize
# * Incorrect amounts charged for purchases you did make
# * Duplicate charges appearing on statements
# * Charges that weren't properly credited or refunded
# * Subscriptions or recurring charges you tried to cancel
# * Merchant billing errors or fraudulent transactions
#
# *List created by Claude from this prompt:*
# > I am looking at data from the CFPB, explain what these issues mean:<br>
# Managing an account<br>
# Improper use of your report<br>
# Incorrect information on your report<br>
# Problem with a purchase shown on your statement<br>

# %%
#building a dataframe to see the number of complaints per bank, used reset_index to maintain the descending value order of the complaint counts
bank_complaint_counts = bank_complaints['Company'].value_counts().reset_index()
bank_complaint_counts.columns = ['Company', 'Complaint Count']

#bar plot to visualize the number of complaints for each bank
plt.figure(figsize=(12,6))
sns.barplot(y='Company', x='Complaint Count', data=bank_complaint_counts, hue='Company',palette='mako')
plt.title('Number of Complaints by Bank')
plt.xlabel('Number of Complaints')
plt.ylabel('Bank')
plt.show()

# %%
#adding a column to bank_complaint_counts that counts the aggregate of 'Timely response?' == 'Yes' for each bank
timely_responses = bank_complaints[bank_complaints['Timely response?'] == 'Yes']['Company'].value_counts().reset_index()
timely_responses.columns = ['Company', 'Timely Response Count'] 

# merging complaint counts and timely responses 
merged_bank_data = pd.merge(bank_complaint_counts, timely_responses, on='Company', how='left')
merged_bank_data['% Timely Response'] = (merged_bank_data['Timely Response Count'] / merged_bank_data['Complaint Count']) * 100
merged_bank_data
# Out:
#                                   Company  Complaint Count  \
# 0                   WELLS FARGO & COMPANY            20722
# 1       CAPITAL ONE FINANCIAL CORPORATION            17019
# 2                    JPMORGAN CHASE & CO.            15615
# 3   BANK OF AMERICA, NATIONAL ASSOCIATION            14315
# 4                          CITIBANK, N.A.             9796
# 5                     SYNCHRONY FINANCIAL             7095
# 6                AMERICAN EXPRESS COMPANY             6116
# 7                           DISCOVER BANK             5211
# 8               NAVY FEDERAL CREDIT UNION             4335
# 9                            U.S. BANCORP             4183
# 10           TRUIST FINANCIAL CORPORATION             3550
# 11             TD BANK US HOLDING COMPANY             3445
# 12                    ALLY FINANCIAL INC.             3351
# 13                 GOLDMAN SACHS BANK USA             2954
# 14                 BARCLAYS BANK DELAWARE             2758
# 15           SANTANDER HOLDINGS USA, INC.             2670
# 16                          PNC Bank N.A.             2382
# 17         CITIZENS FINANCIAL GROUP, INC.             2031
#
#     Timely Response Count  % Timely Response
# 0                   20722         100.000000
# 1                   17018          99.994124
# 2                   15615         100.000000
# 3                   13718          95.829549
# 4                    9796         100.000000
# 5                    7095         100.000000
# 6                    6114          99.967299
# 7                    5211         100.000000
# 8                    4335         100.000000
# 9                    4183         100.000000
# 10                   3544          99.830986
# 11                   3444          99.970972
# 12                   3350          99.970158
# 13                   2945          99.695328
# 14                   2758         100.000000
# 15                   2667          99.887640
# 16                   2382         100.000000
# 17                   2031         100.000000

# %%
#aggregating the number of complaints by the month (pull month from date received column)
#ended up being useless... but kept this for reference

consumer['Month'] = pd.to_datetime(consumer['Date received'], format='mixed').dt.to_period('M')
monthly_complaints = consumer['Month'].value_counts().sort_index().reset_index()
monthly_complaints.columns = ['Month', 'Complaint Count']
monthly_complaints
# Out:
#       Month  Complaint Count
# 0   2023-01            93936
# 1   2023-02            86541
# 2   2023-03           110643
# 3   2023-04            97087
# 4   2023-05           106216
# 5   2023-06           104429
# 6   2023-07           106776
# 7   2023-08           119715
# 8   2023-09           112887
# 9   2023-10           117433
# 10  2023-11           113370
# 11  2023-12           123074

# %%
# trying to understand count of complaints by state from the bank_complaints dataframe
#noticed that the 'State' symbol DC is for district of columbia, updated the Excel file population data from Census to match that
state_complaints = bank_complaints['State'].value_counts().reset_index()
state_complaints.columns = ['State', 'Complaint Count']
state_complaints.head()
# Out:
#   State  Complaint Count
# 0    CA            18074
# 1    FL            14077
# 2    TX            11050
# 3    NY            10402
# 4    GA             7155

# %%
# population by state data from Census data (ACS estimates)
population_data = pd.read_excel('PopulationbyState.xlsx')
population_data.head()
# Out:
#    State Name State Symbol  Total Population  Over 18 Population
# 0     Alabama           AL           5157699             4022842
# 1      Alaska           AK            740133              565186
# 2     Arizona           AZ           7582384             5994209
# 3    Arkansas           AR           3088354             2386510
# 4  California           CA          39431263            31012711

# %%
# merging state complaint counts with population data to get complaints as a ratio of population (CFPB noted that complaints are higher in states with larger populations)
state_population_complaints = pd.merge(state_complaints, population_data, left_on='State', right_on='State Symbol', how='left')
state_population_complaints['Complaints per 100k'] = (state_population_complaints['Complaint Count'] / state_population_complaints['Total Population']) * 100000

#noticed null values in states, since some were places like Puerto Rico and Virgin Islands (territories)
state_population_complaints = state_population_complaints.dropna(subset=['State Symbol'])

# ordering by complaint ratio
state_population_complaints = state_population_complaints.sort_values(by='Complaints per 100k', ascending=False)
state_population_complaints.head()
# Out:
#    State  Complaint Count            State Name State Symbol  \
# 28    DC              790  District of Columbia           DC
# 4     GA             7155               Georgia           GA
# 30    DE              635              Delaware           DE
# 17    NV             1972                Nevada           NV
# 1     FL            14077               Florida           FL
#
#     Total Population  Over 18 Population  Complaints per 100k
# 28          702250.0            572419.0           112.495550
# 4         11180878.0           8640127.0            63.993186
# 30         1051917.0            838204.0            60.365979
# 17         3267467.0           2579031.0            60.352561
# 1         23372215.0          18872523.0            60.229636

# %%
state_population_complaints.tail()
# Out:
#    State  Complaint Count    State Name State Symbol  Total Population  \
# 31    OK              625      Oklahoma           OK         4095393.0
# 36    IA              476          Iowa           IA         3241488.0
# 45    MT              160       Montana           MT         1137233.0
# 32    KY              613      Kentucky           KY         4588372.0
# 51    ND               78  North Dakota           ND          796568.0
#
#     Over 18 Population  Complaints per 100k
# 31           3129179.0            15.261051
# 36           2510913.0            14.684614
# 45            904578.0            14.069236
# 32           3562700.0            13.359858
# 51            611305.0             9.792008

# %%
state_population_complaints['Complaints per 100k'].describe()
# Out:
# count     51.000000
# mean      30.918132
# std       18.453125
# min        9.792008
# 25%       18.154788
# 50%       25.470648
# 75%       37.743474
# max      112.495550
# Name: Complaints per 100k, dtype: float64
